# %% [markdown]
# # Rock and Mineral Clubs
#
# Scrape all of the rock and mineral clubs listed at https://rocktumbler.com/blog/rock-and-mineral-clubs/ (but don't just cut and paste!)
#
# Save a CSV called `rock-clubs.csv` with the name of the club, their URL, and the city they're located in.
#
# **Bonus**: Add a column for the state. There are a few ways to do this, but knowing that `element.parent` goes 'up' one element might be helpful.
#
# * _**Hint:** The name of the club and the city are both inside of td elements, and they aren't distinguishable by class. Instead you'll just want to ask for all of the tds and then just ask for the text from the first or second one._
# * _**Hint:** If you use BeautifulSoup, you can select elements by attributes other than class or id._

# %%
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get("https://rocktumbler.com/blog/rock-and-mineral-clubs/")
doc = BeautifulSoup(response.text)

# %%
name = []

# %%
clubs = doc.find_all('td', width ='60%')

# %%
for club in clubs:
    name.append(club.text)

# %%
location = []

# %%
cities = doc.find_all('td', width ='40%')

# %%
for city in cities:
    location.append(city.text)

# %%
website = []
urls = doc.find_all('a')
for url in urls[37:]:
    link = url.attrs
    website.append(url)

# %%
import pandas as pd

# %%
df = pd.DataFrame(list(zip(name, location, website)),columns=['club','city', 'url'])

# %%
df
# Out:
#                                                   club  \
# 0                   Alabama Mineral & Lapidary Society
# 1                            Dothan Gem & Mineral Club
# 2                   Huntsville Gem and Mineral Society
# 3                            Mobile Rock & Gem Society
# 4                     Montgomery Gem & Mineral Society
# 5                        Chugach Gem & Mineral Society
# 6                         Mat-Su Rock and Mineral Club
# 7                    Apache Junction Rock and Gem Club
# 8                          Black Canyon City Rock Club
# 9                   Daisy Mountain Rock & Mineral Club
# 10                   Gila County Gem & Mineral Society
# 11                       Huachuca Mineral and Gem Club
# 12                   Lake Havasu Gem & Mineral Society
# 13                    Mineralogical Society of Arizona
# 14                           Mingus Gem & Mineral Club
# 15                            Mohave County Gemstoners
# 16                            Old Pueblo Lapidary Club
# 17                         Prescott Gem & Mineral Club
# 18           Quartzsite Roadrunners Gem & Mineral Club
# 19                                     Rockhounds West
# 20                           Sedona Gem & Mineral Club
# 21                    Silvery Colorado River Rock Club
# 22                       Sunsites Gem and Mineral Club
# 23                      Tucson Gem and Mineral Society
# 24                              Verde River Rockhounds
# 25                     West Valley Rock & Mineral Club
# 26                   White Mountain Gem & Mineral Club
# 27                  Wickenburg Gem and Mineral Society
# 28   Central Arkansas Gem, Mineral and Geology Society
# 29            Northwest Arkansas Gem & Mineral Society
# ..                                                 ...
# 454                   Marysville Rock & Gem Club, Inc.
# 455                      Mount Baker Rock And Gem Club
# 456                  North American Miners Association
# 457                   North Puget Sound Facetors Guild
# 458              Northwest Paleontological Association
# 459                        Panorama Gem & Mineral Club
# 460                 Puyallup Valley Gem & Mineral Club
# 461                           Skagit Rock and Gem Club
# 462                          Spokane Rock Rollers Club
# 463              North Seattle Lapidary & Mineral Club
# 464               Washington Agate and Mineral Society
# 465                             West Seattle Rock Club
# 466                         Yakima Rock & Mineral Club
# 467                          Kanawha Rock and Gem Club
# 468                          Prehistoric West Virginia
# 469                      West Virginia Fossil Club Inc
# 470         Badger Lapidary & Geological Society, Inc.
# 471                      Coulee Rock Club of La Crosse
# 472           Heart of Wisconsin Gem & Mineral Society
# 473                  Kettle Moraine Geological Society
# 474                                  Lakeland Gem Club
# 475                       Madison Gem and Mineral Club
# 476          Northwest Wisconsin Gem & Mineral Society
# 477                         Oshkosh Earth Science Club
# 478                     Racine Geological Society, Inc
# 479                         Weis'n'Miners Geology Club
# 480                       Wisconsin Geological Society
# 481                               Cody 59ers Rock Club
# 482                   Riverton Mineral and Gem Society
# 483              Wyoming State Mineral and Gem Society
#
#                            city  \
# 0                    Birmingham
# 1                        Dothan
# 2                    Huntsville
# 3                        Mobile
# 4                    Montgomery
# 5                     Anchorage
# 6                        Palmer
# 7               Apache Junction
# 8             Black Canyon City
# 9                        Anthem
# 10                        Miami
# 11                 Sierra Vista
# 12             Lake Havasu City
# 13                   Scottsdale
# 14                   Cottonwood
# 15                      Kingman
# 16                       Tucson
# 17              Prescott Valley
# 18                   Quartzsite
# 19                      Phoenix
# 20                       Sedona
# 21                Bullhead City
# 22                       Pearce
# 23                       Tucson
# 24                   Cottonwood
# 25                      Buckeye
# 26                     Show Low
# 27                   Wickenburg
# 28                  Little Rock
# 29               Siloam Springs
# ..                          ...
# 454                  Marysville
# 455                  Bellingham
# 456                        Kent
# 457                Mount Vernon
# 458                 Puget Sound
# 459                       Arden
# 460                    Puyallup
# 461                  Mt. Vernon
# 462              Spokane Valley
# 463                     Seattle
# 464                     Olympia
# 465                     Seattle
# 466                      Yakima
# 467                  Charleston
# 468                  Morgantown
# 469                  Clarksburg
# 470                      Monroe
# 471                   La Crosse
# 472  Marshfield & Stevens Point
# 473                    Pewaukee
# 474                    Minocqua
# 475                     Madison
# 476                     Cameron
# 477                     Oshkosh
# 478                      Racine
# 479                     Menasha
# 480                  West Allis
# 481                        Cody
# 482                    Riverton
# 483                        Cody
#
#                                                    url
# 0    <a href="http://www.lapidaryclub.com/">Alabama...
# 1    <a href="http://www.wiregrassrockhounds.com/">...
# 2    <a href="http://huntsvillegms.org/">Huntsville...
# 3    <a href="http://www.mobilerockandgem.com/">Mob...
# 4    <a href="http://montgomerygemandmineralsociety...
# 5                                    <a name="ak"></a>
# 6    <a href="http://www.chugachgemandmineralsociet...
# 7    <a href="http://matsurockclub.com/">Mat-Su Roc...
# 8                                    <a name="az"></a>
# 9    <a href="http://www.ajrockclub.com/">Apache Ju...
# 10   <a href="http://www.bccrockclub.mysite.com/">B...
