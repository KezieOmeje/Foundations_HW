# %% [markdown]
# # Texas Licenses
#
# We originall got our dataset from the [License Files page](https://www.license.state.tx.us/licensesearch/licfile.asp) from the Texas Department of Licensing and Regulation, but they've changed around since then! I'm pretty sure it's [this dataset](https://www.opendatanetwork.com/dataset/data.texas.gov/7358-krk7), but we'll just use a local version instead of the most current.

# %% [markdown]
# # PART ONE: OPENING UP OUR DATASET

# %% [markdown]
# ## 0. Do your setup
#
# Import what you need to import, etc.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## 1. Open the file
#
# We'll start with `licfile.csv`, which is a list of licenses.

# %%
df = pd.read_csv('licfile.csv', dtype={'MAILCOUNTYCODE': str, 'EXPIRATION': str})
# Out:
# /Users/chikezieomeje/.pyenv/versions/3.6.5/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (1,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## 2. That looks terrible, let's add column names.
#
# It apparently doesn't have headers! **Read the file in again, but setting your own column names**. Their [current data dictionary might not perfectly match](https://www.opendatanetwork.com/dataset/data.texas.gov/7358-krk7), but you can use it to understand what the columns are. For the dataset we're using, the order goes like this:
#
# * LICTYPE
# * LICNUMBER
# * BIZCOUNTY
# * BIZNAME
# * BIZLINE1
# * BIZLINE2
# * BIZCITYSTATE
# * BIZTELEPHONE
# * EXPIRATION
# * OWNER
# * MAILLINE1
# * MAILLINE2
# * MAILCITYSTATE
# * MAILCOUNTYCODE
# * MAILCOUNTY
# * MAILZIP
# * TELEPHONE
# * LICSUBTYPE
# * CEFLAG
#
# **Note:** You can rename the columns to things that make sense - "expiration" is a little more manageable than "LICENSE EXPIRATION DATE (MMDDCCYY)". I've named my License Type column LICTYPE, so if you haven't you'll have to change the rest of my sample code to match.

# %%
df.columns = ['LICTYPE', 'LICNUMBER', 'BIZCOUNTY', 'BIZNAME', 'BIZLINE1', 'BIZLINE2', 'BIZCITYSTATE', 'BIZTELEPHONE', 'EXPIRATION', 'OWNER', 'MAILLINE1', 'MAILLINE2', 'MAILCITYSTATE', 'MAILCOUNTYCODE', 'MAILCOUNTY', 'MAILZIP', 'TELEPHONE', 'LICSUBTYPE', 'CEFLAG']

# %%
df.dtypes
# Out:
# LICTYPE            object
# LICNUMBER          object
# BIZCOUNTY          object
# BIZNAME            object
# BIZLINE1          float64
# BIZLINE2          float64
# BIZCITYSTATE      float64
# BIZTELEPHONE      float64
# EXPIRATION          int64
# OWNER              object
# MAILLINE1          object
# MAILLINE2          object
# MAILCITYSTATE      object
# MAILCOUNTYCODE    float64
# MAILCOUNTY         object
# MAILZIP            object
# TELEPHONE          object
# LICSUBTYPE         object
# CEFLAG             object
# dtype: object

# %% [markdown]
# # 3. Force string columns to be strings
#
# The county code and expiration dates are being read in as numbers, which is going to cause some trouble later on. You can force a column to be a certain type (most usually strings) when reading it in with the following code:
#
#     df = pd.read_csv("your-filename.csv", dtype={"colname1": str, "colname2": str})
#
# You don't need to do it for every column, just the ones you want to force!
#
# **Re-import the file, forcing the expiration date, license number, mailing address county code, mailing zip code and telephone to all be strings.**

# %%
df[["EXPIRATION", "MAILCOUNTYCODE"]] = df[["EXPIRATION", "MAILCOUNTYCODE"]].astype(str)

# %% [markdown]
# Check the data types of your columns to be sure! If you do it right they'll be `object` (not `str`, oddly).

# %%
df.dtypes
# Out:
# LICTYPE            object
# LICNUMBER          object
# BIZCOUNTY          object
# BIZNAME            object
# BIZLINE1          float64
# BIZLINE2          float64
# BIZCITYSTATE      float64
# BIZTELEPHONE      float64
# EXPIRATION         object
# OWNER              object
# MAILLINE1          object
# MAILLINE2          object
# MAILCITYSTATE      object
# MAILCOUNTYCODE     object
# MAILCOUNTY         object
# MAILZIP            object
# TELEPHONE          object
# LICSUBTYPE         object
# CEFLAG             object
# dtype: object

# %% [markdown]
# ## 4. Convert those expiration dates from MMDDYYYY to YYYY-MM-DD
#
# List slicing forever! It's the thing with the `[]`. There are like five ways to do this one.

# %%
df['EXPIRATION'] = pd.to_datetime(df['EXPIRATION'].astype(str), format = '%Y/%m/%d', errors = 'ignore')

# %% [markdown]
# Check the first five expirations to make sure they look right.

# %%
df.EXPIRATION.head()
# Out:
# 0   NaT
# 1   NaT
# 2   NaT
# 3   NaT
# 4   NaT
# Name: EXPIRATION, dtype: datetime64[ns]

# %% [markdown]
# # PART TWO: LOOKING AT LICENSES

# %% [markdown]
# ## 5. What are the top 10 most common licenses?

# %%
df.LICTYPE.value_counts().head(10)
# Out:
# Cosmetology Operator        151206
# Apprentice Electrician      110593
# Cosmetology Manicurist       49563
# Journeyman Electrician       38170
# A/C Technician               27959
# Cosmetology Esthetician      23613
# Cosmetology Beauty Salon     23577
# Master Electrician           16810
# A/C Contractor               16376
# Barber, Class A              16019
# Name: LICTYPE, dtype: int64

# %% [markdown]
# ## 6. What are the top 10 least common?

# %%
df.LICTYPE.value_counts().tail(10)
# Out:
# Registered Accessibility Specialist CE Provider    8
# Mobile Cosmetology Esthetician Specialty Saloon    5
# Barber Hair Braiding Shop                          4
# Barber Hair Weaving Shop                           4
# Booting CE Provider                                3
# Cosmetology Wig Instructor                         2
# Mobile Cosmetology Manicure Specialty Saloon       2
# Mobile Cosmetology Esthetician/Manicure Saloon     2
# Licensed Court Interpreter CE Provider             2
# Legal Service Contract Admin                       1
# Name: LICTYPE, dtype: int64

# %% [markdown]
# ## 7. Try to select everyone who is any type of electrician.
#
# You're going to get an error about `"cannot index with vector containing NA / NaN values"`. Let's work our way in there.

# %%
# Yes I know I left this in here, it's a learning experience!
df[df['LICTYPE'].str.contains("Electrician", na =False)]
# Out:
#                             LICTYPE LICNUMBER     BIZCOUNTY  \
# 47024        Apprentice Electrician     30244     ROBERTSON
# 47025        Apprentice Electrician     30798         BEXAR
# 47026        Apprentice Electrician     30802        HARRIS
# 47027        Apprentice Electrician     31875         TITUS
# 47028        Apprentice Electrician     31876         TITUS
# 47029        Apprentice Electrician     32428        HARRIS
# 47030        Apprentice Electrician     32440        TRAVIS
# 47031        Apprentice Electrician     32442          CASS
# 47032        Apprentice Electrician     32450        HARRIS
# 47033        Apprentice Electrician     32453     GALVESTON
# 47034        Apprentice Electrician     33313        HARRIS
# 47035        Apprentice Electrician     33316    WILLIAMSON
# 47036        Apprentice Electrician     33329     GALVESTON
# 47037        Apprentice Electrician     33335        HARRIS
# 47038        Apprentice Electrician     33336      BRAZORIA
# 47039        Apprentice Electrician     33337    MONTGOMERY
# 47040        Apprentice Electrician     33339        HARRIS
# 47041        Apprentice Electrician     33342         LAMAR
# 47042        Apprentice Electrician     33343      BRAZORIA
# 47043        Apprentice Electrician     33353        HARRIS
# 47044        Apprentice Electrician     33355      BRAZORIA
# 47045        Apprentice Electrician     33357        BURNET
# 47046        Apprentice Electrician     33363     GALVESTON
# 47047        Apprentice Electrician     33365        HARRIS
# 47048        Apprentice Electrician     33368     GALVESTON
# 47049        Apprentice Electrician     33369        HARRIS
# 47050        Apprentice Electrician     33778        HARRIS
# 47051        Apprentice Electrician     33779      BRAZORIA
# 47052        Apprentice Electrician     33783     GALVESTON
# 47053        Apprentice Electrician     33790        HARRIS
# ...                             ...       ...           ...
# 569518  Apprentice Sign Electrician    393100     GALVESTON
# 569519  Apprentice Sign Electrician    393101        DALLAS
# 569520  Apprentice Sign Electrician    393102        DALLAS
# 569521  Apprentice Sign Electrician    393212        HARRIS
# 569522  Apprentice Sign Electrician    393213        HARRIS
# 569523  Apprentice Sign Electrician    393214  OUT OF STATE
# 569524  Apprentice Sign Electrician    393215       WILLACY
# 569525  Apprentice Sign Electrician    393216        DALLAS
# 569526  Apprentice Sign Electrician    393217        DALLAS
# 569527  Apprentice Sign Electrician    393218        UVALDE
# 569528  Apprentice Sign Electrician    393399       KAUFMAN
# 569529  Apprentice Sign Electrician    393400        HARRIS
# 569530  Apprentice Sign Electrician    393401        HARRIS
# 569531  Apprentice Sign Electrician    393402      VICTORIA
# 569532  Apprentice Sign Electrician    393403        HARRIS
# 569533  Apprentice Sign Electrician    393404    MONTGOMERY
# 569534  Apprentice Sign Electrician    393523          BELL
# 569535  Apprentice Sign Electrician    393524     FORT BEND
# 569536  Apprentice Sign Electrician    393525       TARRANT
# 569537  Apprentice Sign Electrician    393526         ELLIS
# 569538  Apprentice Sign Electrician    393527        TRAVIS
# 569539  Apprentice Sign Electrician    393528        DALLAS
# 569540  Apprentice Sign Electrician    393606        DALLAS
# 569541  Apprentice Sign Electrician    393607       CAMERON
# 569542  Apprentice Sign Electrician    393608        HARRIS
# 569543  Apprentice Sign Electrician    393609        PARKER
# 569544  Apprentice Sign Electrician    393610  OUT OF STATE
# 569545  Apprentice Sign Electrician    393611  OUT OF STATE
# 569546  Apprentice Sign Electrician    393612       WICHITA
# 569547  Apprentice Sign Electrician    393613        ORANGE
#
#                           BIZNAME  BIZLINE1  BIZLINE2  BIZCITYSTATE  \
# 47024            BOLTON, MARION N       NaN       NaN           NaN
# 47025        GONZALEZ, FELIX G JR       NaN       NaN           NaN
# 47026           HERNANDEZ, RUFINO       NaN       NaN           NaN
# 47027          COPELAND, MARCUS A       NaN       NaN           NaN
# 47028           ANGLIN, DAVID LEE       NaN       NaN           NaN
# 47029          VALLEJO, ARMANDO E       NaN       NaN           NaN
# 47030         RODRIGUEZ, REYNALDO       NaN       NaN           NaN
# 47031            TERRY, ALAN D JR       NaN       NaN           NaN
# 47032            TREVINO, ADIEL A       NaN       NaN           NaN
# 47033        ROACHELL, LAWRENCE S       NaN       NaN           NaN
# 47034             RUSSELL, MARY A       NaN       NaN           NaN
# 47035         BRIZENDINE, DEREK L       NaN       NaN           NaN
# 47036             ALARCON, JUAN A       NaN       NaN           NaN
# 47037   HERRERA ZAPATA, GUMECINDO       NaN       NaN           NaN
# 47038          MARTINEZ, GILBERTO       NaN       NaN           NaN
# 47039              FLORES, JAVIER       NaN       NaN           NaN
# 47040               NGUYEN, DUC T       NaN       NaN           NaN
# 47041            SANCHEZ, EFREN G       NaN       NaN           NaN
# 47042           MCBRIDE, DEBORA K       NaN       NaN           NaN
# 47043           GARZA, REYNALDO D       NaN       NaN           NaN
# 47044         OLISON, DARRYL D SR       NaN       NaN           NaN
# 47045           INGRAM, MICHAEL P       NaN       NaN           NaN
# 47046        HARTER, RICHARD J JR       NaN       NaN           NaN
# 47047           MADRIZ, ALEJANDRO       NaN       NaN           NaN
# 47048              MOUNTS, TODD A       NaN       NaN           NaN
# 47049            OSBORNE, JIMMY L       NaN       NaN           NaN
# 47050            BOTELLO, JESUS B       NaN       NaN           NaN
# 47051          DELGADO, SEVERIANO       NaN       NaN           NaN
# 47052         GARCIA, FRANCISCO J       NaN       NaN           NaN
# 47053                CRUZ, JUAN S       NaN       NaN           NaN
# ...                           ...       ...       ...           ...
# 569518             NAPOLI, ERON W       NaN       NaN           NaN
# 569519               BRISENO, NOE       NaN       NaN           NaN
# 569520       ALMOHAMMADI, SEYED B       NaN       NaN           NaN
# 569521           GONZALES, JUAN G       NaN       NaN           NaN
# 569522          NOEMI , NAVARRETE       NaN       NaN           NaN
# 569523          MARTINEZ, ANTHONY       NaN       NaN           NaN
# 569524            MIGUEL, SALAZAR       NaN       NaN           NaN
# 569525        CALDERON, ANTONIO F       NaN       NaN           NaN
# 569526            JALITT, CLAUDIO       NaN       NaN           NaN
# 569527      SANCHEZ, ESTEBAN I SR       NaN       NaN           NaN
# 569528            PICKENS, THOMAS       NaN       NaN           NaN
# 569529             FLORES, MIGUEL       NaN       NaN           NaN
# 569530             MUNIZ, BRAYN F       NaN       NaN           NaN
# 569531         HARRISON, THOMAS D       NaN       NaN           NaN
# 569532    BESIMER, FREDERIC B III       NaN       NaN           NaN
# 569533        GOTT, CHRISTOPHER J       NaN       NaN           NaN
# 569534      MONTGOMERY, TRISTAN D       NaN       NaN           NaN
# 569535                SOTO, DANNY       NaN       NaN           NaN
# 569536         WASHINGTON, JOSHUA       NaN       NaN           NaN
# 569537         MARTINEZ, BENJAMIN       NaN       NaN           NaN
# 569538        LOPEZ LEDEZMA, JOSE       NaN       NaN           NaN
# 569539           URBINA, LEONARDO       NaN       NaN           NaN
# 569540          STEPHEN, SCOTT SR       NaN       NaN           NaN
# 569541            ORTIZ, HECTOR O       NaN       NaN           NaN
# 569542          MORGAN, DOUGLAS A       NaN       NaN           NaN
# 569543               ORTEGA, JUAN       NaN       NaN           NaN
# 569544             BARR, SYLVIA M       NaN       NaN           NaN
# 569545       MALFAVON, SALVADOR H       NaN       NaN           NaN
# 569546          ARANDA, JOSE A SR       NaN       NaN           NaN
# 569547            ORTIZ, CARLOS M       NaN       NaN           NaN
#
#         BIZTELEPHONE EXPIRATION                      OWNER  \
# 47024            NaN        NaT           BOLTON, MARION N
# 47025            NaN        NaT       GONZALEZ, FELIX G JR
# 47026            NaN        NaT          HERNANDEZ, RUFINO
# 47027            NaN        NaT         COPELAND, MARCUS A
# 47028            NaN        NaT          ANGLIN, DAVID LEE
# 47029            NaN        NaT         VALLEJO, ARMANDO E
# 47030            NaN        NaT        RODRIGUEZ, REYNALDO
# 47031            NaN        NaT           TERRY, ALAN D JR
# 47032            NaN        NaT           TREVINO, ADIEL A
# 47033            NaN        NaT       ROACHELL, LAWRENCE S
# 47034            NaN        NaT            RUSSELL, MARY A
# 47035            NaN        NaT        BRIZENDINE, DEREK L
# 47036            NaN        NaT            ALARCON, JUAN A
# 47037            NaN        NaT  HERRERA ZAPATA, GUMECINDO
# 47038            NaN        NaT         MARTINEZ, GILBERTO
# 47039            NaN        NaT             FLORES, JAVIER
# 47040            NaN        NaT              NGUYEN, DUC T
# 47041            NaN        NaT           SANCHEZ, EFREN G
# 47042            NaN        NaT          MCBRIDE, DEBORA K
# 47043            NaN        NaT          GARZA, REYNALDO D
# 47044            NaN        NaT        OLISON, DARRYL D SR
# 47045            NaN        NaT          INGRAM, MICHAEL P
# 47046            NaN        NaT       HARTER, RICHARD J JR
# 47047            NaN        NaT          MADRIZ, ALEJANDRO
# 47048            NaN        NaT             MOUNTS, TODD A
# 47049            NaN        NaT           OSBORNE, JIMMY L
# 47050            NaN        NaT           BOTELLO, JESUS B
# 47051            NaN        NaT         DELGADO, SEVERIANO
# 47052            NaN        NaT        GARCIA, FRANCISCO J
# 47053            NaN        NaT               CRUZ, JUAN S
# ...              ...        ...                        ...
# 569518           NaN        NaT             NAPOLI, ERON W
# 569519           NaN        NaT               BRISENO, NOE
# 569520           NaN        NaT       ALMOHAMMADI, SEYED B
# 569521           NaN        NaT           GONZALES, JUAN G
# 569522           NaN        NaT          NOEMI , NAVARRETE
# 569523           NaN        NaT          MARTINEZ, ANTHONY
# 569524           NaN        NaT            MIGUEL, SALAZAR
# 569525           NaN        NaT        CALDERON, ANTONIO F
# 569526           NaN        NaT            JALITT, CLAUDIO
# 569527           NaN        NaT      SANCHEZ, ESTEBAN I SR
# 569528           NaN        NaT            PICKENS, THOMAS
# 569529           NaN        NaT             FLORES, MIGUEL
# 569530           NaN        NaT             MUNIZ, BRAYN F
# 569531           NaN        NaT         HARRISON, THOMAS D
# 569532           NaN        NaT    BESIMER, FREDERIC B III
# 569533           NaN        NaT        GOTT, CHRISTOPHER J
# 569534           NaN        NaT      MONTGOMERY, TRISTAN D
# 569535           NaN        NaT                SOTO, DANNY
# 569536           NaN        NaT         WASHINGTON, JOSHUA
# 569537           NaN        NaT         MARTINEZ, BENJAMIN
# 569538           NaN        NaT        LOPEZ LEDEZMA, JOSE
# 569539           NaN        NaT           URBINA, LEONARDO
# 569540           NaN        NaT          STEPHEN, SCOTT SR
# 569541           NaN        NaT            ORTIZ, HECTOR O
# 569542           NaN        NaT          MORGAN, DOUGLAS A
# 569543           NaN        NaT               ORTEGA, JUAN
# 569544           NaN        NaT             BARR, SYLVIA M
# 569545           NaN        NaT       MALFAVON, SALVADOR H
# 569546           NaN        NaT          ARANDA, JOSE A SR
# 569547           NaN        NaT            ORTIZ, CARLOS M
#
#                        MAILLINE1                    MAILLINE2  \
# 47024      2262 HARBOR BOLTON RD                          NaN
# 47025           8507 TIMBER BELT                          NaN
# 47026          1719 ROBINHOOD ST                          NaN
# 47027          201 N MADISON AVE                          NaN
# 47028               8066 FM 1001                          NaN
# 47029       3903 ERBY ST TRLR 88                          NaN
# 47030         10905 SHAWN LEE CV                          NaN
# 47031                605 KEASLER                          NaN
# 47032              3824 LYDIA ST                          NaN
# 47033       115 LAUREL MEADOW CT                          NaN
# 47034       16734 SUMMER DAWN LN                          NaN
# 47035       1900 COUNTY ROAD 228                          NaN
# 47036               4205 24TH ST                          NaN
# 47037         12031 REEDCREST ST                          NaN
# 47038                 PO BOX 705                          NaN
# 47039   5402 FM 1488 RD APT 1124                          NaN
# 47040            12503 LEADER ST                          NaN
# 47041              509 8TH ST SE                          NaN
# 47042                PO BOX 3463                          NaN
# 47043    6806 ALDERSON ST # 6806                          NaN
# 47044            137 WILLIAMS LN                          NaN
# 47045           506 SHADY OAK ST                          NaN
# 47046               2291 MARY LN                          NaN
# 47047            108 GRANTHAM RD                          NaN
# 47048          2705 S HOUSTON DR                          NaN
# 47049      3021 QUAIL HOLLOW CIR                          NaN
# 47050       402 GARNER RD APT 62                          NaN
# 47051          8422 BROOKSIDE RD                          NaN
# 47052           4205 24TH STREET                          NaN
# 47053          9611 STOCKWELL DR                          NaN
# ...                          ...                          ...
# 569518      10612 FM 1764 RD # 4                          NaN
# 569519           4006 WINDSOR DR                          NaN
# 569520    224 SAMUEL BLVD APT 6K                          NaN
# 569521       10407 COPPERDALE LN                          NaN
# 569522            6931 SIGNAT DR                          NaN
# 569523              121 KUNZE DR                          NaN
# 569524           382 TAMPICO AVE                          NaN
# 569525           11139 DENTON DR                          NaN
# 569526        1125 SHADYGLEN CIR                          NaN
# 569527        451 N HOMESTEAD RD                          NaN
# 569528            203 W ALAMO ST                          NaN
# 569529          9634 SALTILLO ST                          NaN
# 569530            205 ISHMEAL ST                          NaN
# 569531        13202 N NAVARRO ST                          NaN
# 569532                   STE 400  24501 HUFSMITH KOHRVILLE RD
# 569533      842 COUNTY ROAD 3709                          NaN
# 569534            4001 WAGON TRL                          NaN
# 569535            27255 KATY FWY                          NaN
# 569536            105 BAYONNE DR                          NaN
# 569537          350 TRUMBULL CIR                          NaN
# 569538                 PO BOX 78                          NaN
# 569539             607 MIDWAY RD                          NaN
# 569540        1206 W STRONG PKWY                          NaN
# 569541          2864 GLYNWOOD DR                          NaN
# 569542            1301 THOMAS DR                          NaN
# 569543               128 JUAN CT                          NaN
# 569544         1015 RIVERVIEW DR                          NaN
# 569545          1237 E CENTER ST                          NaN
# 569546           1108 IRELAND ST                          NaN
# 569547              480 BLAND DR                          NaN
#
#                        MAILCITYSTATE MAILCOUNTYCODE    MAILCOUNTY MAILZIP  \
# 47024         FRANKLIN TX 77856-5367          395.0     ROBERTSON   77856
# 47025      SAN ANTONIO TX 78250-4478           29.0         BEXAR   78250
# 47026         PASADENA TX 77502-2218          201.0        HARRIS   77502
# 47027   MOUNT PLEASANT TX 75455-3944          449.0         TITUS   75455
# 47028        COOKVILLE TX 75558-3064          449.0         TITUS   75558
# 47029          HOUSTON TX 77087-1250          201.0        HARRIS   77087
# 47030           AUSTIN TX 78753-3363          453.0        TRAVIS   78753
# 47031   HUGHES SPRINGS TX 75656-2575           67.0          CASS   75656
# 47032          HOUSTON TX 77021-6125          201.0        HARRIS   77021
# 47033        LA MARQUE TX 77568-2497          167.0     GALVESTON   77568
# 47034          HOUSTON TX 77095-1253          201.0        HARRIS   77095
# 47035         FLORENCE TX 76527-3903          491.0    WILLIAMSON   76527
# 47036        DICKINSON TX 77539-8172          167.0     GALVESTON   77539
# 47037          HOUSTON TX 77085-1113          201.0        HARRIS   77085
# 47038         ROSHARON TX 77583-0705           39.0      BRAZORIA   77583
# 47039         MAGNOLIA TX 77354-3578          339.0    MONTGOMERY   77354
# 47040          HOUSTON TX 77072-2468          201.0        HARRIS   77072
# 47041            PARIS TX 75460-7329          277.0         LAMAR   75460
# 47042     LAKE JACKSON TX 77566-3463           39.0      BRAZORIA   77566
# 47043          HOUSTON TX 77020-3244          201.0        HARRIS   77020
# 47044            ALVIN TX 77511-1043           39.0      BRAZORIA   77511
# 47045           BURNET TX 78611-2639           53.0        BURNET   78611
# 47046        DICKINSON TX 77539-9276          167.0     GALVESTON   77539
# 47047          BAYTOWN TX 77521-4217          201.0        HARRIS   77521
# 47048        LA MARQUE TX 77568-5015          167.0     GALVESTON   77568
# 47049          BAYTOWN TX 77521-2015          201.0        HARRIS   77521
# 47050         PASADENA TX 77502-2108          201.0        HARRIS   77502
# 47051         PEARLAND TX 77581-7317           39.0      BRAZORIA   77581
# 47052        DICKINSON TX 77539-8172          167.0     GALVESTON   77539
# 47053          HOUSTON TX 77083-5940          201.0        HARRIS   77083
# ...                              ...            ...           ...     ...
# 569518        SANTA FE TX 77510-8061          167.0     GALVESTON   77510
# 569519         GARLAND TX 75042-5207          113.0        DALLAS   75042
# 569520         COPPELL TX 75019-5262          113.0        DALLAS   75019
# 569521         HOUSTON TX 77064-7145          201.0        HARRIS   77064
# 569522         HOUSTON TX 77041-2718          201.0        HARRIS   77041
# 569523   SAINT CHARLES MO 63303-5928          999.0  OUT OF STATE   63303
# 569524    RAYMONDVILLE TX 78580-1747          489.0       WILLACY   78580
# 569525          DALLAS TX 75229-4706          113.0        DALLAS   75229
# 569526      RICHARDSON TX 75081-3720          113.0        DALLAS   75081
# 569527          UVALDE TX 78801-7666          463.0        UVALDE   78801
# 569528         TERRELL TX 75160-2130          257.0       KAUFMAN   75160
# 569529         HOUSTON TX 77013-3829          201.0        HARRIS   77013
# 569530         HOUSTON TX 77076-3911          201.0        HARRIS   77076
# 569531        VICTORIA TX 77904-1404          469.0      VICTORIA   77904
# 569532         TOMBALL TX 77375-6932          201.0        HARRIS   77375
# 569533       SPLENDORA TX 77372-9537          339.0    MONTGOMERY   77372
# 569534          TEMPLE TX 76502-2121           27.0          BELL   76502
# 569535            KATY TX 77494-1073          157.0     FORT BEND   77494
# 569536       MANSFIELD TX 76063-5526          439.0       TARRANT   76063
# 569537          FERRIS TX 75125-8413          139.0         ELLIS   75125
# 569538           MANOR TX 78653-0078          453.0        TRAVIS   78653
# 569539      SEAGOVILLE TX 75159-1913          113.0        DALLAS   75159
# 569540   GRAND PRAIRIE TX 75050-5330          113.0        DALLAS   75050
# 569541     BROWNSVILLE TX 78526-4418           61.0       CAMERON   78526
# 569542     FRIENDSWOOD TX 77546-2022          201.0        HARRIS   77546
# 569543     HUDSON OAKS TX 76087-8337          367.0        PARKER   76087
# 569544        FAIRMONT WV 26554-8309          999.0  OUT OF STATE   26554
# 569545       KINGSPORT TN 37660-4945          999.0  OUT OF STATE   37660
# 569546   WICHITA FALLS TX 76301-7837          485.0       WICHITA   76301
# 569547     BRIDGE CITY TX 77611-4614          361.0        ORANGE   77611
#
#          TELEPHONE LICSUBTYPE CEFLAG
# 47024   9798284713         AE      N
# 47025   2104887491         AE      N
# 47026   7133824802         AE      N
# 47027   9035634950         AE      N
# 47028   9039462547         AE      N
# 47029   8325285241         AE      N
# 47030   7372474738         AE      N
# 47031   9036392017         AE      N
# 47032   7134406945         AE      N
# 47033   4095390843         AE      N
# 47034   8323098491         AE      N
# 47035   2543192035         AE      N
# 47036   8327381356         AE      N
# 47037   7137214669         AE      N
# 47038   7133920280         AE      N
# 47039   7138225726         AE      N
# 47040   7132691041         AE      N
# 47041   9032276918         AE      N
# 47042   9796658700         AE      N
# 47043   7136762352         AE      N
# 47044   4097399612         AE      N
# 47045   5124702626         AE      N
# 47046   2819102908         AE      N
# 47047   8328530763         AE      N
# 47048   3462080924         AE      N
# 47049   8325972890         AE      N
# 47050   8323509473         AE      N
# 47051   8327369000         AE      N
# 47052   8327381356         AE      N
# 47053   7139722948         AE      N
# ...            ...        ...    ...
# 569518  4099253357         SA      N
# 569519  2144042443         SA      N
# 569520  9728393089         SA      N
# 569521  8329960375         SA      N
# 569522  2813454488         SA      N
# 569523  6363730961         SA      N
# 569524  9567896672         SA      N
# 569525  9722417446         SA      N
# 569526  2144757318         SA      N
# 569527  8309002628         SA      N
# 569528  4694745309         SA      N
# 569529  8322989252         SA      N
# 569530  8327397104         SA      N
# 569531  3617039035         SA      N
# 569532  3134072437         SA      N
# 569533  2816223970         SA      N
# 569534  2549135913         SA      N
# 569535  2813922828         SA      N
# 569536  8177514838         SA      N
# 569537  2148836327         SA      N
# 569538  7372028067         SA      N
# 569539  2145361782         SA      N
# 569540  4692164741         SA      N
# 569541  9565591718         SA      N
# 569542  4094975341         SA      N
# 569543  8173746117         SA      N
# 569544  3047779007         SA      N
# 569545  4237656317         SA      N
# 569546  9408674318         SA      N
# 569547  4093133718         SA      N
#
# [171838 rows x 19 columns]

# %% [markdown]
# ## 8. How many of the rows of LICTYPE are NaN?

# %%
df[df['LICTYPE'].isna()]
# Out:
#        LICTYPE       LICNUMBER   BIZCOUNTY                   BIZNAME  \
# 181037     NaN  BLRINS00000552         NaN         MARTIN, KENNITH A
# 181038     NaN  BLRINS00000803         NaN            POWELL, GENE G
# 181039     NaN  BLRINS00000807         NaN         POWELL, KENNETH D
# 181040     NaN  BLRINS00000867    HAMILTON           BRYAN, RICKEY L
# 181041     NaN  BLRINS00000900      HARRIS          URICH, MICHAEL A
# 181042     NaN  BLRINS00000912         NaN          MIKEL, STEPHEN J
# 181043     NaN  BLRINS00000925         NaN        WASHINGTON, JOHN H
# 181044     NaN  BLRINS00000971      HARRIS             VARA JR, RUDY
# 181045     NaN  BLRINS00000994         NaN              JONES, DON C
# 181046     NaN  BLRINS00000999  WILLIAMSON            BURNS, KEITH R
# 181047     NaN  BLRINS00001001         NaN          THOMAS, ALFRED B
# 181048     NaN  BLRINS00001021         NaN            BLUEMEL, JOE O
# 181049     NaN  BLRINS00001033         NaN          ALFORD, RONALD E
# 181050     NaN  BLRINS00001066         NaN         NELSON, RICHARD R
# 181051     NaN  BLRINS00001069         NaN           WALKER, BILLY K
# 181052     NaN  BLRINS00001083      TRAVIS         WENDLER, CURTIS P
# 181053     NaN  BLRINS00001102         NaN          COTTEN, TRAVIS O
# 181054     NaN  BLRINS00001106         NaN        TILLMAN, WILLIAM D
# 181055     NaN  BLRINS00001115     WICHITA          GILMORE, KEITH L
# 181056     NaN  BLRINS00001117         NaN           NOEL JR, PAUL M
# 181057     NaN  BLRINS00001126         NaN           ANDREWS, GARY A
# 181058     NaN  BLRINS00001136         NaN           GARNER, BOBBY D
# 181059     NaN  BLRINS00001137         NaN           GOODMAN, GARY G
# 181060     NaN  BLRINS00001162         NaN         FISHER, TIMOTHY R
# 181061     NaN  BLRINS00001187         NaN           MASSEY, JAMES W
# 181062     NaN  BLRINS00001260         NaN            KREFT, DAVID J
# 181063     NaN  BLRINS00001261         NaN         MASTERS, ALBERT D
# 181064     NaN  BLRINS00001317         NaN          LITTLE, DENNIS L
# 181065     NaN  BLRINS00001346         NaN              WYATT, ROY L
# 181066     NaN  BLRINS00001362         NaN        ANDERSON, NORMAN J
# ...        ...             ...         ...                       ...
# 492735     NaN  INSTDE00009974      DALLAS         RAGLAND, ANDREA B
# 492736     NaN  INSTDE00009975     EL PASO         DE LA PENA, MARIO
# 492737     NaN  INSTDE00009980  MONTGOMERY           HUTYRA, DAVID J
# 492738     NaN  INSTDE00009986      HARRIS          MINER, DAVID LEE
# 492739     NaN  INSTDE00009989      HARRIS      ROBERTS, LONNIE EARL
# 492740     NaN  INSTDE00009990   JEFFERSON      DARK, DANIEL HERBERT
# 492741     NaN  INSTDE00009993      COLLIN    HOLLINGER, SHERRY LYNN
# 492742     NaN  INSTDE00009994      DALLAS      VINSON, RONALD DUANE
# 492743     NaN  INSTDE00009994      DALLAS      VINSON, RONALD DUANE
# 492744     NaN  JLMELE00317656         NaN        MILLS, ROBBIE LYNN
# 492745     NaN  JLMELE00321819         NaN          MALCOM, ROBERT L
# 492746     NaN  JLMELE00336107         NaN        CONNER, CARLOS ELI
# 492747     NaN  JLMELE00336556         NaN       MORENO, EDGAR ALLEN
# 492748     NaN  JLMELE00338802         NaN       SMITH, KEVIN EDWARD
# 492749     NaN  JLMELE00340170         NaN  ESPITIA, CHRISTOPHER LEE
# 492750     NaN  JLMELE00348670         NaN         CONTRERAS, DANIEL
# 492751     NaN  JLMELE00349788         NaN             YANEZ, JOSE A
# 492752     NaN  JLMELE00352281         NaN      SCOTT, KELLEN ARCHER
# 492753     NaN  JLMELE00353082         NaN         PEREDEZ, ERIC LEE
# 492754     NaN  JLMELE00358548         NaN       MORENO, ELGIN NILES
# 492755     NaN  JLMELE00358955         NaN        WILLIAMS, MEJIAS S
# 492756     NaN  JLMELE00366277         NaN    WALKER, LEONARD THOMAS
# 492757     NaN  JLMELE00367149         NaN          GONZALES, ADOLPH
# 492758     NaN  JLMELE00370491         NaN  CUNNINGHAM, WILLIAM E JR
# 492759     NaN  JLMELE00371952         NaN         RYAN, EDWARD PAGE
# 492760     NaN  JLMELE00375983         NaN       GUERRA, TIMOTHY LEE
# 492761     NaN  JLMELE00377523         NaN  FIERRO, JACK CHRISTOPHER
# 492762     NaN  JLMELE00378055         NaN        PARKS, EVAN THOMAS
# 492763     NaN  JLMELE00386987         NaN      HERNANDEZ, ARTHUR JR
# 492764     NaN  JLMELE00388171         NaN      HERNANDEZ, ARTHUR SR
#
#         BIZLINE1  BIZLINE2  BIZCITYSTATE  BIZTELEPHONE EXPIRATION  \
# 181037       NaN       NaN           NaN           NaN        NaT
# 181038       NaN       NaN           NaN           NaN        NaT
# 181039       NaN       NaN           NaN           NaN        NaT
# 181040       NaN       NaN           NaN           NaN        NaT
# 181041       NaN       NaN           NaN           NaN        NaT
# 181042       NaN       NaN           NaN           NaN        NaT
# 181043       NaN       NaN           NaN           NaN        NaT
# 181044       NaN       NaN           NaN           NaN        NaT
# 181045       NaN       NaN           NaN           NaN        NaT
# 181046       NaN       NaN           NaN           NaN        NaT
# 181047       NaN       NaN           NaN           NaN        NaT
# 181048       NaN       NaN           NaN           NaN        NaT
# 181049       NaN       NaN           NaN           NaN        NaT
# 181050       NaN       NaN           NaN           NaN        NaT
# 181051       NaN       NaN           NaN           NaN        NaT
# 181052       NaN       NaN           NaN           NaN        NaT
# 181053       NaN       NaN           NaN           NaN        NaT
# 181054       NaN       NaN           NaN           NaN        NaT
# 181055       NaN       NaN           NaN           NaN        NaT
# 181056       NaN       NaN           NaN           NaN        NaT
# 181057       NaN       NaN           NaN           NaN        NaT
# 181058       NaN       NaN           NaN           NaN        NaT
# 181059       NaN       NaN           NaN           NaN        NaT
# 181060       NaN       NaN           NaN           NaN        NaT
# 181061       NaN       NaN           NaN           NaN        NaT
# 181062       NaN       NaN           NaN           NaN        NaT
# 181063       NaN       NaN           NaN           NaN        NaT
# 181064       NaN       NaN           NaN           NaN        NaT
# 181065       NaN       NaN           NaN           NaN        NaT
# 181066       NaN       NaN           NaN           NaN        NaT
# ...          ...       ...           ...           ...        ...
# 492735       NaN       NaN           NaN           NaN        NaT
# 492736       NaN       NaN           NaN           NaN        NaT
# 492737       NaN       NaN           NaN           NaN        NaT
# 492738       NaN       NaN           NaN           NaN        NaT
# 492739       NaN       NaN           NaN           NaN        NaT
# 492740       NaN       NaN           NaN           NaN        NaT
# 492741       NaN       NaN           NaN           NaN        NaT
# 492742       NaN       NaN           NaN           NaN        NaT
# 492743       NaN       NaN           NaN           NaN        NaT
# 492744       NaN       NaN           NaN           NaN        NaT
# 492745       NaN       NaN           NaN           NaN        NaT
# 492746       NaN       NaN           NaN           NaN        NaT
# 492747       NaN       NaN           NaN           NaN        NaT
# 492748       NaN       NaN           NaN           NaN        NaT
# 492749       NaN       NaN           NaN           NaN        NaT
# 492750       NaN       NaN           NaN           NaN        NaT
# 492751       NaN       NaN           NaN           NaN        NaT
# 492752       NaN       NaN           NaN           NaN        NaT
# 492753       NaN       NaN           NaN           NaN        NaT
# 492754       NaN       NaN           NaN           NaN        NaT
# 492755       NaN       NaN           NaN           NaN        NaT
# 492756       NaN       NaN           NaN           NaN        NaT
# 492757       NaN       NaN           NaN           NaN        NaT
# 492758       NaN       NaN           NaN           NaN        NaT
# 492759       NaN       NaN           NaN           NaN        NaT
# 492760       NaN       NaN           NaN           NaN        NaT
# 492761       NaN       NaN           NaN           NaN        NaT
# 492762       NaN       NaN           NaN           NaN        NaT
# 492763       NaN       NaN           NaN           NaN        NaT
# 492764       NaN       NaN           NaN           NaN        NaT
#
#                            OWNER                     MAILLINE1 MAILLINE2  \
# 181037         MARTIN, KENNITH A                           NaN       NaN
# 181038            POWELL, GENE G                           NaN       NaN
# 181039         POWELL, KENNETH D                           NaN       NaN
# 181040           BRYAN, RICKEY L                           NaN       NaN
# 181041          URICH, MICHAEL A               9807 OAKMONT DR       NaN
# 181042          MIKEL, STEPHEN J                           NaN       NaN
# 181043        WASHINGTON, JOHN H                           NaN       NaN
# 181044             VARA JR, RUDY       14531 FM 529 RD STE 135       NaN
# 181045              JONES, DON C                           NaN       NaN
# 181046            BURNS, KEITH R          3006 FOUNTAINWOOD DR       NaN
# 181047          THOMAS, ALFRED B                           NaN       NaN
# 181048            BLUEMEL, JOE O                           NaN       NaN
# 181049          ALFORD, RONALD E                           NaN       NaN
# 181050         NELSON, RICHARD R                           NaN       NaN
# 181051           WALKER, BILLY K                           NaN       NaN
# 181052         WENDLER, CURTIS P               1507 HOUSTON ST       NaN
# 181053          COTTEN, TRAVIS O                           NaN       NaN
# 181054        TILLMAN, WILLIAM D                           NaN       NaN
# 181055          GILMORE, KEITH L                    PO BOX 925       NaN
# 181056           NOEL JR, PAUL M                           NaN       NaN
# 181057           ANDREWS, GARY A                           NaN       NaN
# 181058           GARNER, BOBBY D                           NaN       NaN
# 181059           GOODMAN, GARY G                           NaN       NaN
# 181060         FISHER, TIMOTHY R                           NaN       NaN
# 181061           MASSEY, JAMES W                           NaN       NaN
# 181062            KREFT, DAVID J                           NaN       NaN
# 181063         MASTERS, ALBERT D                           NaN       NaN
# 181064          LITTLE, DENNIS L                           NaN       NaN
# 181065              WYATT, ROY L                           NaN       NaN
# 181066        ANDERSON, NORMAN J                           NaN       NaN
# ...                          ...                           ...       ...
# 492735         RAGLAND, ANDREA B                    800 LEMONS       NaN
# 492736         DE LA PENA, MARIO            7533 LUZ DE LUMBRE       NaN
# 492737           HUTYRA, DAVID J          31111 SILVER VILLAGE       NaN
# 492738          MINER, DAVID LEE            13834 FAIR PARK DR       NaN
# 492739      ROBERTS, LONNIE EARL        11927 GARDENGLEN DRIVE       NaN
# 492740      DARK, DANIEL HERBERT               996 W  LUCAS DR       NaN
# 492741    HOLLINGER, SHERRY LYNN            904 HIGH MEADOW DR       NaN
# 492742      VINSON, RONALD DUANE            1905 ANNETTE DRIVE       NaN
# 492743      VINSON, RONALD DUANE            1905 ANNETTE DRIVE       NaN
# 492744        MILLS, ROBBIE LYNN                 698 N LAKE DR       NaN
# 492745          MALCOM, ROBERT L              312 SW ALPINE DR       NaN
# 492746        CONNER, CARLOS ELI                 1208 AVENUE S       NaN
# 492747       MORENO, EDGAR ALLEN                  112 CEDAR RD       NaN
# 492748       SMITH, KEVIN EDWARD              33215 WOODTON CT       NaN
# 492749  ESPITIA, CHRISTOPHER LEE                 218 CIRCLE DR       NaN
# 492750         CONTRERAS, DANIEL                    1601 AVE M       NaN
# 492751             YANEZ, JOSE A               1504 FREEMAN RD       NaN
# 492752      SCOTT, KELLEN ARCHER               401 RINGGOLD RD       NaN
# 492753         PEREDEZ, ERIC LEE                 1216 AVENUE D       NaN
# 492754       MORENO, ELGIN NILES                  3210 FENN ST       NaN
# 492755        WILLIAMS, MEJIAS S           4519 PLEASANT DRIVE       NaN
# 492756    WALKER, LEONARD THOMAS       9401 MIDNIGHT CREEK WAY       NaN
# 492757          GONZALES, ADOLPH                   207 N AVE C       NaN
# 492758  CUNNINGHAM, WILLIAM E JR               23406 SAXON WAY       NaN
# 492759         RYAN, EDWARD PAGE  4027 NORTH TWIN BUTTES COURT       #12
# 492760       GUERRA, TIMOTHY LEE              1701 S RENFRO ST       NaN
# 492761  FIERRO, JACK CHRISTOPHER                 208 E 98TH ST       NaN
# 492762        PARKS, EVAN THOMAS                 417 CASPER CT       NaN
# 492763      HERNANDEZ, ARTHUR JR                  3107 30TH ST       NaN
# 492764      HERNANDEZ, ARTHUR SR            10114 VALENCIA AVE       NaN
#
#                     MAILCITYSTATE MAILCOUNTYCODE    MAILCOUNTY MAILZIP  \
# 181037                        NaN            nan           NaN       0
# 181038                        NaN            nan           NaN       0
# 181039                        NaN            nan           NaN       0
# 181040                        NaN          193.0           NaN   76531
# 181041     LA PORTE TX 77571-4180          201.0        HARRIS   77571
# 181042                        NaN            nan           NaN       0
# 181043                        NaN            nan           NaN       0
# 181044      HOUSTON TX 77095-5290          201.0        HARRIS   77095
# 181045                        NaN            nan           NaN       0
# 181046   GEORGETOWN TX 78633-1934          491.0    WILLIAMSON   78633
# 181047                        NaN            nan           NaN       0
# 181048                        NaN            nan           NaN       0
# 181049                        NaN            nan           NaN       0
# 181050                        NaN            nan           NaN       0
# 181051                        NaN            nan           NaN       0
# 181052       AUSTIN TX 78756-1300          453.0        TRAVIS   78756
# 181053                        NaN            nan           NaN       0
# 181054                        NaN            nan           NaN       0
# 181055    IOWA PARK TX 76367-0925          485.0       WICHITA   76367
# 181056                        NaN            nan           NaN       0
# 181057                        NaN            nan           NaN       0
# 181058                        NaN            nan           NaN       0
# 181059                        NaN            nan           NaN       0
# 181060                        NaN            nan           NaN       0
# 181061                        NaN            nan           NaN       0
# 181062                        NaN            nan           NaN       0
# 181063                        NaN            nan           NaN       0
# 181064                        NaN            nan           NaN       0
# 181065                        NaN            nan           NaN       0
# 181066                        NaN            nan           NaN       0
# ...                           ...            ...           ...     ...
# 492735        CEDAR HILL TX 75104          113.0        DALLAS   75104
# 492736           EL PASO TX 79912          141.0       EL PASO   79912
# 492737            SPRING TX 77386          339.0    MONTGOMERY   77386
# 492738           HOUSTON TX 77014          201.0        HARRIS   77014
# 492739           HOUSTON TX 77070          201.0        HARRIS   77070
# 492740          BEAUMONT TX 77706          245.0     JEFFERSON   77706
# 492741             ALLEN TX 75002           85.0        COLLIN   75002
# 492742            IRVING TX 75061          113.0        DALLAS   75061
# 492743            IRVING TX 75061          113.0        DALLAS   75061
# 492744   GLADEWATER TX 75647-3838          183.0         GREGG   75647
# 492745    PLAINVIEW TX 79072-8811          189.0          HALE   79072
# 492746            EUNICE NM 88231          999.0  OUT OF STATE   88231
# 492747   BIG SPRING TX 79720-4234          227.0        HOWARD   79720
# 492748     FULSHEAR TX 77441-4057          157.0     FORT BEND   77441
# 492749           WINTERS TX 79567          399.0       RUNNELS   79567
# 492750         SEAGRAVES TX 79359          165.0        GAINES   79359
# 492751  DENVER CITY TX 79323-9548          501.0        YOAKUM   79323
# 492752       BROWNSVILLE TX 78520           61.0       CAMERON   78520
# 492753    LEVELLAND TX 79336-5547          219.0       HOCKLEY   79336
# 492754   BIG SPRING TX 79720-3500          227.0        HOWARD   79720
# 492755           MIDLAND TX 79703          329.0       MIDLAND   79703
# 492756  BAKERSFIELD CA 93310-4510          999.0  OUT OF STATE   93310
# 492757           WAELDER TX 78959          177.0      GONZALES   78959
# 492758      HOCKLEY TX 77447-9574          201.0        HARRIS   77447
# 492759           DOUGLAS AZ 85607          999.0  OUT OF STATE   85607
# 492760       MEADOW TX 79345-3156          445.0         TERRY   79345
# 492761       ODESSA TX 79765-1472          135.0         ECTOR   79765
# 492762      MIDLAND TX 79705-3955          329.0       MIDLAND   79705
# 492763       SNYDER TX 79549-5556          415.0        SCURRY   79549
# 492764      LUBBOCK TX 79424-5056          303.0       LUBBOCK   79424
#
#           TELEPHONE        LICSUBTYPE CEFLAG
# 181037          NaN  Boiler Inspector      N
# 181038          NaN  Boiler Inspector      N
# 181039          NaN  Boiler Inspector      N
# 181040          NaN  Boiler Inspector      N
# 181041   8323155284  Boiler Inspector      N
# 181042          NaN  Boiler Inspector      N
# 181043          NaN  Boiler Inspector      N
# 181044   2817511150  Boiler Inspector      N
# 181045          NaN  Boiler Inspector      N
# 181046   5127507907  Boiler Inspector      N
# 181047          NaN  Boiler Inspector      N
# 181048          NaN  Boiler Inspector      N
# 181049          NaN  Boiler Inspector      N
# 181050          NaN  Boiler Inspector      N
# 181051          NaN  Boiler Inspector      N
# 181052          NaN  Boiler Inspector      N
# 181053          NaN  Boiler Inspector      N
# 181054          NaN  Boiler Inspector      N
# 181055   8327238060  Boiler Inspector      N
# 181056          NaN  Boiler Inspector      N
# 181057          NaN  Boiler Inspector      N
# 181058          NaN  Boiler Inspector      N
# 181059          NaN  Boiler Inspector      N
# 181060          NaN  Boiler Inspector      N
# 181061          NaN  Boiler Inspector      N
# 181062          NaN  Boiler Inspector      N
# 181063          NaN  Boiler Inspector      N
# 181064          NaN  Boiler Inspector      N
# 181065          NaN  Boiler Inspector      N
# 181066          NaN  Boiler Inspector      N
# ...             ...               ...    ...
# 492735  9.72292e+09                DS    NaN
# 492736          NaN                DS    NaN
# 492737  2.81773e+09                DE    NaN
# 492738  8.32238e+09                DE    NaN
# 492739          NaN                DE    NaN
# 492740  4.09927e+09                DS    NaN
# 492741  2.14384e+09                DE    NaN
# 492742  9.72386e+09                DE    NaN
# 492743  9.72386e+09                DS    NaN
# 492744  9.03316e+09                JL      N
# 492745          NaN                JL      N
# 492746          NaN                JL      N
# 492747          NaN                JL      N
# 492748          NaN                JL      N
# 492749          NaN                JL      N
# 492750          NaN                JL      N
# 492751          NaN                JL      N
# 492752          NaN                JL      N
# 492753          NaN                JL      N
# 492754          NaN                JL      N
# 492755          NaN                JL      N
# 492756          NaN                JL      N
# 492757          NaN                JL      N
# 492758          NaN                JL      N
# 492759          NaN                JL      N
# 492760          NaN                JL      N
# 492761          NaN                JL      N
# 492762   7.0724e+09                JL      N
# 492763  3.25574e+09                JL      N
# 492764          NaN                JL      N
#
# [7086 rows x 19 columns]

# %% [markdown]
# Over 7000 licenses don't have types! As a result, when we look for license types with electricians - aka do `df['LICTYPE'].str.contains("Electrician")` - we get three results:
#
# * `True` means `LICTYPE` exists and contains `"Electrician"`
# * `False` means `LICTYPE` exists and does not contain `"Electrician"`
# * `NaN` means `LICTYPE` does not exist for that row

# %% [markdown]
# ## 9. Actually getting everyone who is an electrician

# %%
df[df['LICTYPE'].str.contains("Electrician", na =False)]
# Out:
#                             LICTYPE LICNUMBER     BIZCOUNTY  \
# 47024        Apprentice Electrician     30244     ROBERTSON
# 47025        Apprentice Electrician     30798         BEXAR
# 47026        Apprentice Electrician     30802        HARRIS
# 47027        Apprentice Electrician     31875         TITUS
# 47028        Apprentice Electrician     31876         TITUS
# 47029        Apprentice Electrician     32428        HARRIS
# 47030        Apprentice Electrician     32440        TRAVIS
# 47031        Apprentice Electrician     32442          CASS
# 47032        Apprentice Electrician     32450        HARRIS
# 47033        Apprentice Electrician     32453     GALVESTON
# 47034        Apprentice Electrician     33313        HARRIS
# 47035        Apprentice Electrician     33316    WILLIAMSON
# 47036        Apprentice Electrician     33329     GALVESTON
# 47037        Apprentice Electrician     33335        HARRIS
# 47038        Apprentice Electrician     33336      BRAZORIA
# 47039        Apprentice Electrician     33337    MONTGOMERY
# 47040        Apprentice Electrician     33339        HARRIS
# 47041        Apprentice Electrician     33342         LAMAR
# 47042        Apprentice Electrician     33343      BRAZORIA
# 47043        Apprentice Electrician     33353        HARRIS
# 47044        Apprentice Electrician     33355      BRAZORIA
# 47045        Apprentice Electrician     33357        BURNET
# 47046        Apprentice Electrician     33363     GALVESTON
# 47047        Apprentice Electrician     33365        HARRIS
# 47048        Apprentice Electrician     33368     GALVESTON
# 47049        Apprentice Electrician     33369        HARRIS
# 47050        Apprentice Electrician     33778        HARRIS
# 47051        Apprentice Electrician     33779      BRAZORIA
# 47052        Apprentice Electrician     33783     GALVESTON
# 47053        Apprentice Electrician     33790        HARRIS
# ...                             ...       ...           ...
# 569518  Apprentice Sign Electrician    393100     GALVESTON
# 569519  Apprentice Sign Electrician    393101        DALLAS
# 569520  Apprentice Sign Electrician    393102        DALLAS
# 569521  Apprentice Sign Electrician    393212        HARRIS
# 569522  Apprentice Sign Electrician    393213        HARRIS
# 569523  Apprentice Sign Electrician    393214  OUT OF STATE
# 569524  Apprentice Sign Electrician    393215       WILLACY
# 569525  Apprentice Sign Electrician    393216        DALLAS
# 569526  Apprentice Sign Electrician    393217        DALLAS
# 569527  Apprentice Sign Electrician    393218        UVALDE
# 569528  Apprentice Sign Electrician    393399       KAUFMAN
# 569529  Apprentice Sign Electrician    393400        HARRIS
# 569530  Apprentice Sign Electrician    393401        HARRIS
# 569531  Apprentice Sign Electrician    393402      VICTORIA
# 569532  Apprentice Sign Electrician    393403        HARRIS
# 569533  Apprentice Sign Electrician    393404    MONTGOMERY
# 569534  Apprentice Sign Electrician    393523          BELL
# 569535  Apprentice Sign Electrician    393524     FORT BEND
# 569536  Apprentice Sign Electrician    393525       TARRANT
# 569537  Apprentice Sign Electrician    393526         ELLIS
# 569538  Apprentice Sign Electrician    393527        TRAVIS
# 569539  Apprentice Sign Electrician    393528        DALLAS
# 569540  Apprentice Sign Electrician    393606        DALLAS
# 569541  Apprentice Sign Electrician    393607       CAMERON
# 569542  Apprentice Sign Electrician    393608        HARRIS
# 569543  Apprentice Sign Electrician    393609        PARKER
# 569544  Apprentice Sign Electrician    393610  OUT OF STATE
# 569545  Apprentice Sign Electrician    393611  OUT OF STATE
# 569546  Apprentice Sign Electrician    393612       WICHITA
# 569547  Apprentice Sign Electrician    393613        ORANGE
#
#                           BIZNAME  BIZLINE1  BIZLINE2  BIZCITYSTATE  \
# 47024            BOLTON, MARION N       NaN       NaN           NaN
# 47025        GONZALEZ, FELIX G JR       NaN       NaN           NaN
# 47026           HERNANDEZ, RUFINO       NaN       NaN           NaN
# 47027          COPELAND, MARCUS A       NaN       NaN           NaN
# 47028           ANGLIN, DAVID LEE       NaN       NaN           NaN
# 47029          VALLEJO, ARMANDO E       NaN       NaN           NaN
# 47030         RODRIGUEZ, REYNALDO       NaN       NaN           NaN
# 47031            TERRY, ALAN D JR       NaN       NaN           NaN
# 47032            TREVINO, ADIEL A       NaN       NaN           NaN
# 47033        ROACHELL, LAWRENCE S       NaN       NaN           NaN
# 47034             RUSSELL, MARY A       NaN       NaN           NaN
# 47035         BRIZENDINE, DEREK L       NaN       NaN           NaN
# 47036             ALARCON, JUAN A       NaN       NaN           NaN
# 47037   HERRERA ZAPATA, GUMECINDO       NaN       NaN           NaN
# 47038          MARTINEZ, GILBERTO       NaN       NaN           NaN
# 47039              FLORES, JAVIER       NaN       NaN           NaN
# 47040               NGUYEN, DUC T       NaN       NaN           NaN
# 47041            SANCHEZ, EFREN G       NaN       NaN           NaN
# 47042           MCBRIDE, DEBORA K       NaN       NaN           NaN
# 47043           GARZA, REYNALDO D       NaN       NaN           NaN
# 47044         OLISON, DARRYL D SR       NaN       NaN           NaN
# 47045           INGRAM, MICHAEL P       NaN       NaN           NaN
# 47046        HARTER, RICHARD J JR       NaN       NaN           NaN
# 47047           MADRIZ, ALEJANDRO       NaN       NaN           NaN
# 47048              MOUNTS, TODD A       NaN       NaN           NaN
# 47049            OSBORNE, JIMMY L       NaN       NaN           NaN
# 47050            BOTELLO, JESUS B       NaN       NaN           NaN
# 47051          DELGADO, SEVERIANO       NaN       NaN           NaN
# 47052         GARCIA, FRANCISCO J       NaN       NaN           NaN
# 47053                CRUZ, JUAN S       NaN       NaN           NaN
# ...                           ...       ...       ...           ...
# 569518             NAPOLI, ERON W       NaN       NaN           NaN
# 569519               BRISENO, NOE       NaN       NaN           NaN
# 569520       ALMOHAMMADI, SEYED B       NaN       NaN           NaN
# 569521           GONZALES, JUAN G       NaN       NaN           NaN
# 569522          NOEMI , NAVARRETE       NaN       NaN           NaN
# 569523          MARTINEZ, ANTHONY       NaN       NaN           NaN
# 569524            MIGUEL, SALAZAR       NaN       NaN           NaN
# 569525        CALDERON, ANTONIO F       NaN       NaN           NaN
# 569526            JALITT, CLAUDIO       NaN       NaN           NaN
# 569527      SANCHEZ, ESTEBAN I SR       NaN       NaN           NaN
# 569528            PICKENS, THOMAS       NaN       NaN           NaN
# 569529             FLORES, MIGUEL       NaN       NaN           NaN
# 569530             MUNIZ, BRAYN F       NaN       NaN           NaN
# 569531         HARRISON, THOMAS D       NaN       NaN           NaN
# 569532    BESIMER, FREDERIC B III       NaN       NaN           NaN
# 569533        GOTT, CHRISTOPHER J       NaN       NaN           NaN
# 569534      MONTGOMERY, TRISTAN D       NaN       NaN           NaN
# 569535                SOTO, DANNY       NaN       NaN           NaN
# 569536         WASHINGTON, JOSHUA       NaN       NaN           NaN
# 569537         MARTINEZ, BENJAMIN       NaN       NaN           NaN
# 569538        LOPEZ LEDEZMA, JOSE       NaN       NaN           NaN
# 569539           URBINA, LEONARDO       NaN       NaN           NaN
# 569540          STEPHEN, SCOTT SR       NaN       NaN           NaN
# 569541            ORTIZ, HECTOR O       NaN       NaN           NaN
# 569542          MORGAN, DOUGLAS A       NaN       NaN           NaN
# 569543               ORTEGA, JUAN       NaN       NaN           NaN
# 569544             BARR, SYLVIA M       NaN       NaN           NaN
# 569545       MALFAVON, SALVADOR H       NaN       NaN           NaN
# 569546          ARANDA, JOSE A SR       NaN       NaN           NaN
# 569547            ORTIZ, CARLOS M       NaN       NaN           NaN
#
#         BIZTELEPHONE EXPIRATION                      OWNER  \
# 47024            NaN        NaT           BOLTON, MARION N
# 47025            NaN        NaT       GONZALEZ, FELIX G JR
# 47026            NaN        NaT          HERNANDEZ, RUFINO
# 47027            NaN        NaT         COPELAND, MARCUS A
# 47028            NaN        NaT          ANGLIN, DAVID LEE
# 47029            NaN        NaT         VALLEJO, ARMANDO E
# 47030            NaN        NaT        RODRIGUEZ, REYNALDO
# 47031            NaN        NaT           TERRY, ALAN D JR
# 47032            NaN        NaT           TREVINO, ADIEL A
# 47033            NaN        NaT       ROACHELL, LAWRENCE S
# 47034            NaN        NaT            RUSSELL, MARY A
# 47035            NaN        NaT        BRIZENDINE, DEREK L
# 47036            NaN        NaT            ALARCON, JUAN A
# 47037            NaN        NaT  HERRERA ZAPATA, GUMECINDO
# 47038            NaN        NaT         MARTINEZ, GILBERTO
# 47039            NaN        NaT             FLORES, JAVIER
# 47040            NaN        NaT              NGUYEN, DUC T
# 47041            NaN        NaT           SANCHEZ, EFREN G
# 47042            NaN        NaT          MCBRIDE, DEBORA K
# 47043            NaN        NaT          GARZA, REYNALDO D
# 47044            NaN        NaT        OLISON, DARRYL D SR
# 47045            NaN        NaT          INGRAM, MICHAEL P
# 47046            NaN        NaT       HARTER, RICHARD J JR
# 47047            NaN        NaT          MADRIZ, ALEJANDRO
# 47048            NaN        NaT             MOUNTS, TODD A
# 47049            NaN        NaT           OSBORNE, JIMMY L
# 47050            NaN        NaT           BOTELLO, JESUS B
# 47051            NaN        NaT         DELGADO, SEVERIANO
# 47052            NaN        NaT        GARCIA, FRANCISCO J
# 47053            NaN        NaT               CRUZ, JUAN S
# ...              ...        ...                        ...
# 569518           NaN        NaT             NAPOLI, ERON W
# 569519           NaN        NaT               BRISENO, NOE
# 569520           NaN        NaT       ALMOHAMMADI, SEYED B
# 569521           NaN        NaT           GONZALES, JUAN G
# 569522           NaN        NaT          NOEMI , NAVARRETE
# 569523           NaN        NaT          MARTINEZ, ANTHONY
# 569524           NaN        NaT            MIGUEL, SALAZAR
# 569525           NaN        NaT        CALDERON, ANTONIO F
# 569526           NaN        NaT            JALITT, CLAUDIO
# 569527           NaN        NaT      SANCHEZ, ESTEBAN I SR
# 569528           NaN        NaT            PICKENS, THOMAS
# 569529           NaN        NaT             FLORES, MIGUEL
# 569530           NaN        NaT             MUNIZ, BRAYN F
# 569531           NaN        NaT         HARRISON, THOMAS D
# 569532           NaN        NaT    BESIMER, FREDERIC B III
# 569533           NaN        NaT        GOTT, CHRISTOPHER J
# 569534           NaN        NaT      MONTGOMERY, TRISTAN D
# 569535           NaN        NaT                SOTO, DANNY
# 569536           NaN        NaT         WASHINGTON, JOSHUA
# 569537           NaN        NaT         MARTINEZ, BENJAMIN
# 569538           NaN        NaT        LOPEZ LEDEZMA, JOSE
# 569539           NaN        NaT           URBINA, LEONARDO
# 569540           NaN        NaT          STEPHEN, SCOTT SR
# 569541           NaN        NaT            ORTIZ, HECTOR O
# 569542           NaN        NaT          MORGAN, DOUGLAS A
# 569543           NaN        NaT               ORTEGA, JUAN
# 569544           NaN        NaT             BARR, SYLVIA M
# 569545           NaN        NaT       MALFAVON, SALVADOR H
# 569546           NaN        NaT          ARANDA, JOSE A SR
# 569547           NaN        NaT            ORTIZ, CARLOS M
#
#                        MAILLINE1                    MAILLINE2  \
# 47024      2262 HARBOR BOLTON RD                          NaN
# 47025           8507 TIMBER BELT                          NaN
# 47026          1719 ROBINHOOD ST                          NaN
# 47027          201 N MADISON AVE                          NaN
# 47028               8066 FM 1001                          NaN
# 47029       3903 ERBY ST TRLR 88                          NaN
# 47030         10905 SHAWN LEE CV                          NaN
# 47031                605 KEASLER                          NaN
# 47032              3824 LYDIA ST                          NaN
# 47033       115 LAUREL MEADOW CT                          NaN
# 47034       16734 SUMMER DAWN LN                          NaN
# 47035       1900 COUNTY ROAD 228                          NaN
# 47036               4205 24TH ST                          NaN
# 47037         12031 REEDCREST ST                          NaN
# 47038                 PO BOX 705                          NaN
# 47039   5402 FM 1488 RD APT 1124                          NaN
# 47040            12503 LEADER ST                          NaN
# 47041              509 8TH ST SE                          NaN
# 47042                PO BOX 3463                          NaN
# 47043    6806 ALDERSON ST # 6806                          NaN
# 47044            137 WILLIAMS LN                          NaN
# 47045           506 SHADY OAK ST                          NaN
# 47046               2291 MARY LN                          NaN
# 47047            108 GRANTHAM RD                          NaN
# 47048          2705 S HOUSTON DR                          NaN
# 47049      3021 QUAIL HOLLOW CIR                          NaN
# 47050       402 GARNER RD APT 62                          NaN
# 47051          8422 BROOKSIDE RD                          NaN
# 47052           4205 24TH STREET                          NaN
# 47053          9611 STOCKWELL DR                          NaN
# ...                          ...                          ...
# 569518      10612 FM 1764 RD # 4                          NaN
# 569519           4006 WINDSOR DR                          NaN
# 569520    224 SAMUEL BLVD APT 6K                          NaN
# 569521       10407 COPPERDALE LN                          NaN
# 569522            6931 SIGNAT DR                          NaN
# 569523              121 KUNZE DR                          NaN
# 569524           382 TAMPICO AVE                          NaN
# 569525           11139 DENTON DR                          NaN
# 569526        1125 SHADYGLEN CIR                          NaN
# 569527        451 N HOMESTEAD RD                          NaN
# 569528            203 W ALAMO ST                          NaN
# 569529          9634 SALTILLO ST                          NaN
# 569530            205 ISHMEAL ST                          NaN
# 569531        13202 N NAVARRO ST                          NaN
# 569532                   STE 400  24501 HUFSMITH KOHRVILLE RD
# 569533      842 COUNTY ROAD 3709                          NaN
# 569534            4001 WAGON TRL                          NaN
# 569535            27255 KATY FWY                          NaN
# 569536            105 BAYONNE DR                          NaN
# 569537          350 TRUMBULL CIR                          NaN
# 569538                 PO BOX 78                          NaN
# 569539             607 MIDWAY RD                          NaN
# 569540        1206 W STRONG PKWY                          NaN
# 569541          2864 GLYNWOOD DR                          NaN
# 569542            1301 THOMAS DR                          NaN
# 569543               128 JUAN CT                          NaN
# 569544         1015 RIVERVIEW DR                          NaN
# 569545          1237 E CENTER ST                          NaN
# 569546           1108 IRELAND ST                          NaN
# 569547              480 BLAND DR                          NaN
#
#                        MAILCITYSTATE MAILCOUNTYCODE    MAILCOUNTY MAILZIP  \
# 47024         FRANKLIN TX 77856-5367          395.0     ROBERTSON   77856
# 47025      SAN ANTONIO TX 78250-4478           29.0         BEXAR   78250
# 47026         PASADENA TX 77502-2218          201.0        HARRIS   77502
# 47027   MOUNT PLEASANT TX 75455-3944          449.0         TITUS   75455
# 47028        COOKVILLE TX 75558-3064          449.0         TITUS   75558
# 47029          HOUSTON TX 77087-1250          201.0        HARRIS   77087
# 47030           AUSTIN TX 78753-3363          453.0        TRAVIS   78753
# 47031   HUGHES SPRINGS TX 75656-2575           67.0          CASS   75656
# 47032          HOUSTON TX 77021-6125          201.0        HARRIS   77021
# 47033        LA MARQUE TX 77568-2497          167.0     GALVESTON   77568
# 47034          HOUSTON TX 77095-1253          201.0        HARRIS   77095
# 47035         FLORENCE TX 76527-3903          491.0    WILLIAMSON   76527
# 47036        DICKINSON TX 77539-8172          167.0     GALVESTON   77539
# 47037          HOUSTON TX 77085-1113          201.0        HARRIS   77085
# 47038         ROSHARON TX 77583-0705           39.0      BRAZORIA   77583
# 47039         MAGNOLIA TX 77354-3578          339.0    MONTGOMERY   77354
# 47040          HOUSTON TX 77072-2468          201.0        HARRIS   77072
# 47041            PARIS TX 75460-7329          277.0         LAMAR   75460
# 47042     LAKE JACKSON TX 77566-3463           39.0      BRAZORIA   77566
# 47043          HOUSTON TX 77020-3244          201.0        HARRIS   77020
# 47044            ALVIN TX 77511-1043           39.0      BRAZORIA   77511
# 47045           BURNET TX 78611-2639           53.0        BURNET   78611
# 47046        DICKINSON TX 77539-9276          167.0     GALVESTON   77539
# 47047          BAYTOWN TX 77521-4217          201.0        HARRIS   77521
# 47048        LA MARQUE TX 77568-5015          167.0     GALVESTON   77568
# 47049          BAYTOWN TX 77521-2015          201.0        HARRIS   77521
# 47050         PASADENA TX 77502-2108          201.0        HARRIS   77502
# 47051         PEARLAND TX 77581-7317           39.0      BRAZORIA   77581
# 47052        DICKINSON TX 77539-8172          167.0     GALVESTON   77539
# 47053          HOUSTON TX 77083-5940          201.0        HARRIS   77083
# ...                              ...            ...           ...     ...
# 569518        SANTA FE TX 77510-8061          167.0     GALVESTON   77510
# 569519         GARLAND TX 75042-5207          113.0        DALLAS   75042
# 569520         COPPELL TX 75019-5262          113.0        DALLAS   75019
# 569521         HOUSTON TX 77064-7145          201.0        HARRIS   77064
# 569522         HOUSTON TX 77041-2718          201.0        HARRIS   77041
# 569523   SAINT CHARLES MO 63303-5928          999.0  OUT OF STATE   63303
# 569524    RAYMONDVILLE TX 78580-1747          489.0       WILLACY   78580
# 569525          DALLAS TX 75229-4706          113.0        DALLAS   75229
# 569526      RICHARDSON TX 75081-3720          113.0        DALLAS   75081
# 569527          UVALDE TX 78801-7666          463.0        UVALDE   78801
# 569528         TERRELL TX 75160-2130          257.0       KAUFMAN   75160
# 569529         HOUSTON TX 77013-3829          201.0        HARRIS   77013
# 569530         HOUSTON TX 77076-3911          201.0        HARRIS   77076
# 569531        VICTORIA TX 77904-1404          469.0      VICTORIA   77904
# 569532         TOMBALL TX 77375-6932          201.0        HARRIS   77375
# 569533       SPLENDORA TX 77372-9537          339.0    MONTGOMERY   77372
# 569534          TEMPLE TX 76502-2121           27.0          BELL   76502
# 569535            KATY TX 77494-1073          157.0     FORT BEND   77494
# 569536       MANSFIELD TX 76063-5526          439.0       TARRANT   76063
# 569537          FERRIS TX 75125-8413          139.0         ELLIS   75125
# 569538           MANOR TX 78653-0078          453.0        TRAVIS   78653
# 569539      SEAGOVILLE TX 75159-1913          113.0        DALLAS   75159
# 569540   GRAND PRAIRIE TX 75050-5330          113.0        DALLAS   75050
# 569541     BROWNSVILLE TX 78526-4418           61.0       CAMERON   78526
# 569542     FRIENDSWOOD TX 77546-2022          201.0        HARRIS   77546
# 569543     HUDSON OAKS TX 76087-8337          367.0        PARKER   76087
# 569544        FAIRMONT WV 26554-8309          999.0  OUT OF STATE   26554
# 569545       KINGSPORT TN 37660-4945          999.0  OUT OF STATE   37660
# 569546   WICHITA FALLS TX 76301-7837          485.0       WICHITA   76301
# 569547     BRIDGE CITY TX 77611-4614          361.0        ORANGE   77611
#
#          TELEPHONE LICSUBTYPE CEFLAG
# 47024   9798284713         AE      N
# 47025   2104887491         AE      N
# 47026   7133824802         AE      N
# 47027   9035634950         AE      N
# 47028   9039462547         AE      N
# 47029   8325285241         AE      N
# 47030   7372474738         AE      N
# 47031   9036392017         AE      N
# 47032   7134406945         AE      N
# 47033   4095390843         AE      N
# 47034   8323098491         AE      N
# 47035   2543192035         AE      N
# 47036   8327381356         AE      N
# 47037   7137214669         AE      N
# 47038   7133920280         AE      N
# 47039   7138225726         AE      N
# 47040   7132691041         AE      N
# 47041   9032276918         AE      N
# 47042   9796658700         AE      N
# 47043   7136762352         AE      N
# 47044   4097399612         AE      N
# 47045   5124702626         AE      N
# 47046   2819102908         AE      N
# 47047   8328530763         AE      N
# 47048   3462080924         AE      N
# 47049   8325972890         AE      N
# 47050   8323509473         AE      N
# 47051   8327369000         AE      N
# 47052   8327381356         AE      N
# 47053   7139722948         AE      N
# ...            ...        ...    ...
# 569518  4099253357         SA      N
# 569519  2144042443         SA      N
# 569520  9728393089         SA      N
# 569521  8329960375         SA      N
# 569522  2813454488         SA      N
# 569523  6363730961         SA      N
# 569524  9567896672         SA      N
# 569525  9722417446         SA      N
# 569526  2144757318         SA      N
# 569527  8309002628         SA      N
# 569528  4694745309         SA      N
# 569529  8322989252         SA      N
# 569530  8327397104         SA      N
# 569531  3617039035         SA      N
# 569532  3134072437         SA      N
# 569533  2816223970         SA      N
# 569534  2549135913         SA      N
# 569535  2813922828         SA      N
# 569536  8177514838         SA      N
# 569537  2148836327         SA      N
# 569538  7372028067         SA      N
# 569539  2145361782         SA      N
# 569540  4692164741         SA      N
# 569541  9565591718         SA      N
# 569542  4094975341         SA      N
# 569543  8173746117         SA      N
# 569544  3047779007         SA      N
# 569545  4237656317         SA      N
# 569546  9408674318         SA      N
# 569547  4093133718         SA      N
#
# [171838 rows x 19 columns]

# %% [markdown]
# This doesn't work when trying to select electricians, though, as NaN is a no-go for a filter. We *could* filter out everywhere the LICTYPE is null, but we could also cheat a little and say "replace all of the `NaN` values with `False` values."
#
# `.fillna(False)` will take every `NaN` and replace it with `False`.

# %% [markdown]
# ## 10. What's the most popular kind of electrician?

# %% [markdown]
# ## 11. Graph it, with the largest bar on top.

# %% [markdown]
# ## 12. How many sign electricians are there?
#
# There are a few ways to do this one.

# %% [markdown]
# # PART THREE: LOOKING AT LAST NAMES

# %% [markdown]
# ## 13. Extract every owner's last name
#
# You want everything before the comma. We've done this before (in a few different ways!).
#
# * **Hint:** If you get an error about missing or `NaN` data, you might use `.fillna('')` to replace every empty owner name with an empty string. This might not happen to you, though, depending on how you do it!
#
# * **Hint:** You probably want to do `expand=False` on your extraction to make sure it comes out as a series instead of a dataframe.

# %% [markdown]
# ## 14. Save the last name into a new column
#
# Then check to make sure it exists, and you successfully saved it into the dataframe.

# %% [markdown]
# # 15. What are the ten most popular last names?

# %% [markdown]
# ## 16. What are the most popular licenses for people with the last name Nguyen? Tran? Le?
#
# Those are the top 3 last names in Vietnam.

# %% [markdown]
# ## 17. Now do all of that in one line - most popular licenses for Nguyen, Tran and Le - without using `&`

# %% [markdown]
# ## 18. Most popular licenses for Garcia? Rodriguez? Martinez?
#
# Those are the 3 most common last names for self-identifying Hispanics in the USA.

# %% [markdown]
# ## 19. Most popular license for anyone with a last name that ENDS in `-ez`
#
# The answer is not `.str.contains('ez')`, but it isn't necessarily too different. **Make sure your numbers match mine.**
#
# One way involves a `.str.` method that check if a string ends with something, the other way involves a regular expression that has a "end of the string" marker (similar to how we've used `^` for the start of a string before). If you're thinking about the latter, I might take a look at [this page](http://www.rexegg.com/regex-quickstart.html) under "Anchors and Boundaries".

# %% [markdown]
# ## 20. Get that as a percentage

# %% [markdown]
# # PART FOUR: LOOKING AT FIRST NAMES

# %% [markdown]
# ## 21. Extract the owner's first name
#
# First, a little example of how regular expressions work with pandas.

# %%
# Build a dataframe
sample_df = pd.DataFrame([
    { 'name': 'Mary', 'sentence': "I am 90 years old" },
    { 'name': 'Jack', 'sentence': "I am 4 years old" },
    { 'name': 'Anne', 'sentence': "I am 27 years old" },
    { 'name': 'Joel', 'sentence': "I am 13 years old" },
])
# Look at the dataframe
sample_df

# %%
# Given the sentence, "I am X years old", extract digits from the middle using ()
# Anything you put in () will be saved as an output.
# If you do expand=True it makes you a dataframe, but we don't want that.
sample_df['sentence'].str.extract("I am (\d+) years old", expand=False)

# %%
# Save it into a new column
sample_df['age'] = sample_df['sentence'].str.extract("I am (\d+) years old", expand=False)
sample_df.head()

# %% [markdown]
# **Now let's think about how we're going to extract the first names.** Begin by looking at a few full names.

# %%
df['OWNER'].head(10)

# %% [markdown]
# What can you use to find the first name? It helps to say "this is to the left and this is to the right, and I'm going to take anything in the middle."
#
# Once you figure out how to extract it, you can do a `.head(10)` to just look at the first few.

# %% [markdown]
# ## 22. Saving the owner's first name
#
# Save the name to a new column, `FIRSTNAME`.

# %% [markdown]
# # 23. Examine everyone without a first name
#
# I purposefully didn't do a nicer regex in order to have some screwed-up results. **How many people are there without an entry in the first name column?**
#
# Your numbers might be different than mine.

# %% [markdown]
# What do their names look like?

# %% [markdown]
# ## 24. If it's a problem, you can fix it (if you'd like!)
#
# Maybe you have another regular expression that works better with JUST these people? It really depends on how you've put together your previous regex!
#
# If you'd like to use a separate regex for this group, you can use code like this:
#
# `df.loc[df.FIRSTNAME.isnull(), 'FIRSTNAME'] = .....`
#
# That will only set the `FIRSTNAME` for people where `FIRSTNAME` is null.

# %% [markdown]
# How many empty first names do we have now?

# %% [markdown]
# My code before only worked for people with middle names, but now it got people without middle names, too. Looking much better!

# %% [markdown]
# ## 25. Most popular first names?

# %% [markdown]
# ## 26. Most popular first names for a Cosmetology Operator, Cosmetology Esthetician, Cosmetologist, and okay honestly anything that seems similar?
#
# If you get an error about "cannot index vector containing NA / NaN values" remember `.fillna(False)` - if a row doesn't have a license, it doesn't give a `True`/`False`, so we force all of the empty rows to be `False`.

# %% [markdown]
# ## 27. Most popular first names for anything involving electricity?

# %% [markdown]
# ## 28. Can we be any more obnoxious in this assignment?
#
# Not only are we going to detect gender from first names, but we're also going to use a library that has the terrible name of [sex machine](https://github.com/ferhatelmas/sexmachine/). Once upon a time there was Ruby package named sex machine and everyone was like "come on are you six years old? is this how we do things?" and the guy was like "you're completely right I'm renaming it to [gender detector](https://github.com/bmuller/gender_detector)" and the world was Nice and Good again. Apparently Python didn't get the message.
#
# Except actually sexmachine doesn't work on Python 3 because it's from 300 BC so we're going to use a Python 3 fork called [gender guesser](https://pypi.python.org/pypi/gender-guesser/) (hooray!).
#
# #### Use `pip` or `pip3` to install gender-guesser.

# %%
# !pip install gender-guesser

# %% [markdown]
# #### Test to see that it works

# %%
import gender_guesser.detector as gender

detector = gender.Detector(case_sensitive=False)
detector.get_gender('David')

# %%
detector.get_gender('Jose')

# %%
detector.get_gender('Maria')

# %% [markdown]
# #### Use it on a dataframe
#
# To use something fancy like that on a dataframe, you use `.apply`. Check it out:

# %%
df['FIRSTNAME'].fillna('').apply(lambda name: detector.get_gender(name)).head()

# %% [markdown]
# ## 29. Calculate the gender of everyone's first name and save it to a column
#
# Confirm by see how many people of each gender we have

# %% [markdown]
# ## 30. We like taking risks - get rid of ambiguity
#
# * Combine the `mostly_female` into `female`
# * Combine the `mostly_male` into `male`
# * Replace `andy` (androgynous) and `unknown` with `NaN`
#
# you can get NaN not by making a string, but with `import numpy as np` and then using `np.nan`.

# %%
import numpy as np

# %% [markdown]
# ## 31. Do men or women have more licenses? What is the percentage of unknown genders?

# %% [markdown]
# ## 32. What are the popular unknown- or ambiguous gender first names?
#
# Yours might be different! Mine is a combination of actual ambiguity, cultural bias and dirty data.

# %% [markdown]
# ## 31. What are the most popular licenses for men? For women?

# %% [markdown]
# ## 32. What is the gender breakdown for Property Tax Appraiser? How about anything involving Tow Trucks?
#
# If you're in need, remember your good friend `.fillna(False)` to get rid of NaN values.

# %% [markdown]
# (By the way, what are those tow truck jobs?)

# %% [markdown]
# ## 33. Graph them!
#
# And let's **give them titles** so we know which is which.

# %% [markdown]
# ## 34. Calcuate the gender bias for profession
#
# I spent like an hour on this and then realized a super easy way to do it. Welcome to programming! I'll do this part for you.

# %%
# So when you do .value_counts(), it gives you an index and a value
df[df['GENDER'] == 'male'].LICTYPE.value_counts().head()

# %% [markdown]
# We did `pd.concat` to combine dataframes, but you can also use it to combine series (like the results of `value_counts()`). If you give it a few `value_counts()` and give it some column names it'll make something real nice.

# %%
# All of the values_counts() we will be combining
vc_series = [
    df[df['GENDER'] == 'male'].LICTYPE.value_counts(),
    df[df['GENDER'] == 'female'].LICTYPE.value_counts(),
    df[df['GENDER'].isnull()].LICTYPE.value_counts()
]
# You need axis=1 so it combines them as columns
gender_df = pd.concat(vc_series, axis=1)
gender_df.head()

# %%
# Turn "A/C Contractor" etc into an actual column instead of an index
gender_df.reset_index(inplace=True)
gender_df.head()

# %%
# Rename the columns appropriately
gender_df.columns = ["license", "male", "female", "unknown"]
# Clean up the NaN by replacing them with zeroes
gender_df.fillna(0, inplace=True)
gender_df.head()

# %% [markdown]
# ## 35. Add new columns for total licenses, percent known (not percent unknown!), percent male (of known), percent female (of known)
#
# And replace any `NaN`s with `0`.

# %% [markdown]
# ## 35. What 10 licenses with more than 2,000 people and over 75% known has the most male owners? The most female?

# %% [markdown]
# ## 36. Let's say you have to call a few people about being in a profession dominated by the other gender. What are their phone numbers?
#
# This will involve doing some research in one dataframe, then the other one. I didn't put an answer here because I'm interested in what you come up with!

# %% [markdown]
# ## PART FIVE: Violations
#
# ### 37. Read in **violations.csv** as `violations_df`, make sure it looks right

# %% [markdown]
# ### 38. Combine with your original licenses dataset dataframe to get phone numbers and addresses for each violation. Check that it is 90 rows, 28 columns.

# %% [markdown]
# ## 39. Find each violation involving a failure with records. Use a regular expression.

# %% [markdown]
# ## 40. How much money was each fine? Use a regular expression and .str.extract (we talked about it before!)
#
# Unfortunately large and helpful troubleshooting tip: `$` means "end of a line" in regex, so `.extract` isn't going to accept it as a dollar sign. You need to escape it by using `\$` instead.

# %% [markdown]
# ## 41. Clean those results (no commas, no dollar signs, and it should be an integer) and save it to a new column called `fine`
#
# `.replace` is for *entire cells*, you're interested in `.str.replace`, which treats each value like a string, not like a... pandas thing.
#
# `.astype(int)` will convert it into an integer for you.

# %% [markdown]
# ## 42. Which orders results in the top fines?

# %% [markdown]
# ## 43. Are you still here???
#
# I'm sure impressed.
